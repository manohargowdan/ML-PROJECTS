# %%
# Loading Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv("Cab_Rides.csv")

# %%
data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
data.tail(10)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1145  12/30/2016 10:15  12/30/2016 10:33  Business           Kar?chi
# 1146  12/30/2016 11:31  12/30/2016 11:56  Business           Kar?chi
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business           Kar?chi
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business           Kar?chi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business           Kar?chi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 1145           Kar?chi     2.8  Errand/Supplies
# 1146           Kar?chi     2.9  Errand/Supplies
# 1147           Kar?chi     4.6  Errand/Supplies
# ...

# %%
data.shape
# Out:
# (1155, 7)

# %%
data.isna().sum()
# Out:
# START_DATE*      0
# END_DATE*        0
# CATEGORY*        0
# START*           0
# STOP*            0
# MILES*           0
# PURPOSE*       502
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1155 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1155 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
data.describe()
# Out:
#             MILES*
# count  1155.000000
# mean     10.566840
# std      21.579106
# min       0.500000
# 25%       2.900000
# 50%       6.000000
# 75%      10.400000
# max     310.300000

# %%
data.isna().any()
# Out:
# START_DATE*    False
# END_DATE*      False
# CATEGORY*      False
# START*         False
# STOP*          False
# MILES*         False
# PURPOSE*        True
# dtype: bool

# %% [markdown]
# # EDA For Categorical Variables

# %%
# PURPOSE*

# %%
data["PURPOSE*"].value_counts()
# Out:
# Meeting            187
# Meal/Entertain     160
# Errand/Supplies    128
# Customer Visit     101
# Temporary Site      50
# Between Offices     18
# Moving               4
# Airport/Travel       3
# Charity ($)          1
# Commute              1
# Name: PURPOSE*, dtype: int64

# %%
data["PURPOSE*"].isna().sum()
# Out:
# 502

# %%
data["PURPOSE*"] .fillna("Meeting",inplace=True)

# %%
data["PURPOSE*"].value_counts()
# Out:
# Meeting            689
# Meal/Entertain     160
# Errand/Supplies    128
# Customer Visit     101
# Temporary Site      50
# Between Offices     18
# Moving               4
# Airport/Travel       3
# Charity ($)          1
# Commute              1
# Name: PURPOSE*, dtype: int64

# %%
data["PURPOSE*"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# STOP*

# %%
data["STOP*"].value_counts()
# Out:
# Cary                          203
# Unknown Location              149
# Morrisville                    84
# Whitebridge                    65
# Islamabad                      58
# Durham                         36
# Lahore                         36
# Raleigh                        29
# Kar?chi                        26
# Apex                           17
# Berkeley                       16
# Westpark Place                 16
# R?walpindi                     13
# Kissimmee                      12
# Midtown                        11
# Edgehill Farms                 10
# New Orleans                    10
# Kenner                         10
# Emeryville                      9
# Central                         9
# San Francisco                   8
# Oakland                         8
# Colombo                         8
# Banner Elk                      8
# Downtown                        7
# Orlando                         7
# The Drag                        7
# ...

# %%
data["STOP*"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.catplot(x='CATEGORY*', y='MILES*', hue='STOP*' ,data= data, kind='bar')

# %%
# START*

# %%
data["START*"].value_counts()
# Out:
# Cary                          201
# Unknown Location              148
# Morrisville                    85
# Whitebridge                    68
# Islamabad                      57
# Durham                         37
# Lahore                         36
# Raleigh                        28
# Kar?chi                        27
# Westpark Place                 17
# Apex                           17
# Berkeley                       16
# Midtown                        14
# Kissimmee                      11
# R?walpindi                     11
# Kenner                         11
# New Orleans                    10
# Emeryville                     10
# Downtown                        9
# Orlando                         8
# Central                         8
# Colombo                         8
# Edgehill Farms                  8
# San Francisco                   8
# Banner Elk                      8
# Oakland                         7
# Hazelwood                       7
# ...

# %%
data["START*"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.catplot(x='CATEGORY*', y='MILES*', hue='START*' ,data= data, kind='bar')

# %%
sns.catplot(x='PURPOSE*', y='MILES*',data= data, kind='bar')

# %%
sns.catplot(x='PURPOSE*', y='MILES*', hue='CATEGORY*' ,data= data, kind='bar')

# %%
sns.catplot(x='CATEGORY*', y='MILES*', hue='PURPOSE*' ,data= data, kind='bar')

# %%
# CATEGORY*

# %%
data["CATEGORY*"].value_counts()
# Out:
# Business    1078
# Personal      77
# Name: CATEGORY*, dtype: int64

# %%
data["CATEGORY*"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Continous variabe

# %%
# MILES*

# %%
data.boxplot(column ="MILES*")
# Out:
# <AxesSubplot:>

# %%
p=[ ]
for i in range(1,101):
    xyz = (data['MILES*'].quantile(i/100))
    p.append(xyz)
q=pd.Series(p)

pd.set_option("max_rows", None)
print(q)

plt.figure(figsize=(10,9))
plt.plot(p,'*')
# Out:
# 0       0.700
# 1       0.900
# 2       1.000
# 3       1.100
# 4       1.200
# 5       1.400
# 6       1.478
# 7       1.532
# 8       1.600
# 9       1.700
# 10      1.800
# 11      1.800
# 12      1.900
# 13      2.000
# 14      2.010
# 15      2.100
# 16      2.200
# 17      2.200
# 18      2.300
# 19      2.400
# 20      2.500
# 21      2.600
# 22      2.700
# 23      2.800
# 24      2.900
# 25      3.000
# 26      3.000
# 27      3.100
# 28      3.100
# 29      3.200
# 30      3.300
# 31      3.328
# 32      3.500
# 33      3.700
# 34      3.800
# 35      3.900
# 36      4.000
# 37      4.200
# 38      4.400
# 39      4.500
# 40      4.700
# 41      4.868
# 42      5.000
# 43      5.100
# 44      5.200
# 45      5.384
# 46      5.500
# 47      5.700
# 48      5.800
# 49      6.000
# 50      6.100
# 51      6.100
# 52      6.200
# 53      6.400
# 54      6.600
# 55      6.900
# 56      7.200
# 57      7.400
# 58      7.600
# 59      7.700
# 60      7.900
# 61      8.000
# ...

# %%
sns.boxplot(data['MILES*'])
# Out:
# E:\Anaconda\envs\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='MILES*'>
